# %% [markdown]
# <a href="https://colab.research.google.com/github/adithyarhm/nlp-sentiment_play_store/blob/main/%5BDICODING%5D_scrapping_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Library**

# %%
# Install google-play-scraper untuk scrap data dari google play store
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.6 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
import pandas as pd  # Pandas untuk manipulasi dan analisis data
pd.options.mode.chained_assignment = None  # Menonaktifkan peringatan chaining
import numpy as np  # NumPy untuk komputasi numerik

# %% [markdown]
# # Srcapping Dataset

# %%
from google_play_scraper import app, reviews_all, Sort # Import Sort, reviews_all, dan app dari google_play_scraper

# ID aplikasi
app_ids = ['com.telkom.tracencare']
all_reviews = []

for app_id in app_ids:
    print(f"Scrapping ulasan untuk aplikasi: {app_id}")
    reviews = reviews_all(
        app_id,
        lang='id',                # Bahasa ulasan (default: 'en')
        country='id',             # Negara (default: 'us')
        sort=Sort.MOST_RELEVANT,  # Urutan ulasan (default: Sort.MOST_RELEVANT)
    )
    all_reviews.extend(reviews)

scrapreview = all_reviews
# Out:
# Scrapping ulasan untuk aplikasi: com.telkom.tracencare

# %% [markdown]
# # Loading Dataset

# %%
app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.shape
app_reviews_df.head()
app_reviews_df.to_csv('ulasan_aplikasi.csv', index=False)

# %%
# Membuat DataFrame dari hasil scrapreview
app_reviews_df = pd.DataFrame(scrapreview)

# Menghitung jumlah baris dan kolom dalam DataFrame
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape

# %%
# Menampilkan head dari DataFrame app_reviews_df
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  28f3cf3c-f84e-44bc-afa0-61fe7f78f877  Pengguna Google
# 1  8752184a-0f32-4bc3-8431-63dcadf7fd01  Pengguna Google
# 2  73aa82e6-9748-4f13-9510-3b5ab7c67c74  Pengguna Google
# 3  ac16fec5-2e4d-488a-8118-4d08af4c2011  Pengguna Google
# 4  0ebe3036-05f1-4ca0-ad4c-747f63c862d2  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  saya pertama kali melakukan Cek Kesehatan Grat...      1              4
# 1  Tolong kalau hire Team Tech yang bener, yg kom...      1              9
# 2  akun sudah lama punya, setelah update terbaru ...      1              1
# 3  aplikasi ini aneh, padahal mau daftar malah ga...      1              1
# 4  kacauu, setelah di update malah ga bisa login ...      1             16
#
#   reviewCreatedVersion                  at  \
# 0                8.6.1 2026-03-30 02:04:30
# 1                8.5.1 2026-03-07 05:58:17
# 2                8.6.1 2026-04-08 09:02:48
# 3                8.6.1 2026-04-12 03:47:16
# 4                8.5.0 2026-02-17 04:05:05
#
#                                         replyContent           repliedAt  \
# 0  Halo Healthies,\nTerima kasih telah meluangkan... 2026-03-30 02:05:12
# 1  Halo Healthies,\nTerima kasih telah meluangkan... 2026-03-07 05:59:03
# 2  Halo Healthies,\nTerima kasih telah meluangkan... 2026-04-08 09:02:48
# 3  Halo Healthies,\nTerima kasih telah meluangkan... 2026-04-12 03:47:51
# 4  Halo Healthies,\nTerima kasih telah meluangkan... 2026-02-17 04:05:52
#
#   appVersion
# 0      8.6.1
# 1      8.5.1
# 2      8.6.1
# 3      8.6.1
# 4      8.5.0

# %%
# Menampilkan informasi tentang DataFrame app_reviews_df
app_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296167 entries, 0 to 296166
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reviewId              296167 non-null  object
#  1   userName              296167 non-null  object
#  2   userImage             296167 non-null  object
#  3   content               296167 non-null  object
#  4   score                 296167 non-null  int64
#  5   thumbsUpCount         296167 non-null  int64
#  6   reviewCreatedVersion  252163 non-null  object
#  7   at                    296167 non-null  datetime64[ns]
#  8   replyContent          193464 non-null  object
#  9   repliedAt             193464 non-null  datetime64[ns]
#  10  appVersion            252163 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 24.9+ MB

# %%
# Membuat DataFrame baru (clean_df) dengan menghapus baris yang memiliki nilai yang hilang (NaN) dari app_reviews_df
clean_df = app_reviews_df.dropna()

# %%
# Menampilkan informasi tentang DataFrame clean_df setelah membersihkan nilai yang hilang (NaN)
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 163295 entries, 0 to 283735
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reviewId              163295 non-null  object
#  1   userName              163295 non-null  object
#  2   userImage             163295 non-null  object
#  3   content               163295 non-null  object
#  4   score                 163295 non-null  int64
#  5   thumbsUpCount         163295 non-null  int64
#  6   reviewCreatedVersion  163295 non-null  object
#  7   at                    163295 non-null  datetime64[ns]
#  8   replyContent          163295 non-null  object
#  9   repliedAt             163295 non-null  datetime64[ns]
#  10  appVersion            163295 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 15.0+ MB

# %%
# Menghapus baris duplikat dari DataFrame clean_df
clean_df = clean_df.drop_duplicates()

# Menghitung jumlah baris dan kolom dalam DataFrame clean_df setelah menghapus duplikat
jumlah_ulasan_setelah_hapus_duplikat, jumlah_kolom_setelah_hapus_duplikat = clean_df.shape

# %%
# Mengambil sampel acak dengan 30000 baris karna data hasil scrap terlalu besar bagi saya
clean_df = clean_df.sample(n=30000, random_state=42)

# %%
# Menyimpan ulasan yang sudah dibersihkan dalam file CSV
clean_df.to_csv('ulasan_aplikasi_clean.csv', index=False)
